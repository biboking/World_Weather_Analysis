# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 753

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
    
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current description": city_description})

#If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 1 | barkhan
# Processing Record 3 of Set 1 | avarua
# Processing Record 4 of Set 1 | clyde river
# Processing Record 5 of Set 1 | bengkulu
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | butaritari
# Processing Record 8 of Set 1 | sabang
# Processing Record 9 of Set 1 | la cruz
# Processing Record 10 of Set 1 | vaini
# Processing Record 11 of Set 1 | bud
# Processing Record 12 of Set 1 | vila velha
# Processing Record 13 of Set 1 | victoria
# Processing Record 14 of Set 1 | mahebourg
# Processing Record 15 of Set 1 | mataura
# Processing Record 16 of Set 1 | san gabriel
# Processing Record 17 of Set 1 | ribeira grande
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | sao miguel do araguaia
# Processing Record 20 of Set 1 | thompson
# Processing Record 21 of Set 1 | arraial do cabo
# Processing Record 22 of Set 1 | laguna
# Processing Record 23 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 1 | amarante do maranhao
# Processing Record 25 of Set 1 | busselton
# Processing Record 26 of Set 1 | prachuap khiri khan
# Processing Record 27 of Set 1 | sioux lookout
# Processing Record 28 of Set 1 | abha
# Processing Record 29 of Set 1 | hofn
# Processing Record 30 of Set 1 | port elizabeth
# Processing Record 31 of Set 1 | trairi
# Processing Record 32 of Set 1 | lebu
# Processing Record 33 of Set 1 | sterling
# Processing Record 34 of Set 1 | punta arenas
# Processing Record 35 of Set 1 | buala
# Processing Record 36 of Set 1 | hermanus
# Processing Record 37 of Set 1 | castro
# Processing Record 38 of Set 1 | zhaotong
# Processing Record 39 of Set 1 | nanortalik
# Processing Record 40 of Set 1 | yellowknife
# Processing Record 41 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 1 | hare bay
# Processing Record 43 of Set 1 | tuktoyaktuk
# Processing Record 44 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 45 of Set 1 | barrow
# Processing Record 46 of Set 1 | singkang
# Processing Record 47 of Set 1 | bluff
# Processing Record 48 of Set 1 | yanan
# City not found. Skipping...
# Processing Record 49 of Set 1 | coquimbo
# Processing Record 50 of Set 1 | bredasdorp
# Processing Record 1 of Set 2 | baoshan
# Processing Record 2 of Set 2 | port blair
# Processing Record 3 of Set 2 | kapaa
# Processing Record 4 of Set 2 | bethel
# Processing Record 5 of Set 2 | ushuaia
# Processing Record 6 of Set 2 | touros
# Processing Record 7 of Set 2 | puerto ayora
# Processing Record 8 of Set 2 | wajir
# Processing Record 9 of Set 2 | ulladulla
# Processing Record 10 of Set 2 | upernavik
# Processing Record 11 of Set 2 | katsuura
# Processing Record 12 of Set 2 | songjianghe
# Processing Record 13 of Set 2 | bathsheba
# Processing Record 14 of Set 2 | khunzakh
# Processing Record 15 of Set 2 | kenai
# Processing Record 16 of Set 2 | zhob
# Processing Record 17 of Set 2 | tukrah
# Processing Record 18 of Set 2 | parbhani
# Processing Record 19 of Set 2 | tasiilaq
# Processing Record 20 of Set 2 | new norfolk
# Processing Record 21 of Set 2 | savannah bight
# Processing Record 22 of Set 2 | pevek
# Processing Record 23 of Set 2 | dikson
# Processing Record 24 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 2 | hami
# Processing Record 26 of Set 2 | hambantota
# Processing Record 27 of Set 2 | muros
# Processing Record 28 of Set 2 | grindavik
# Processing Record 29 of Set 2 | sur
# Processing Record 30 of Set 2 | labuhan
# Processing Record 31 of Set 2 | santa rosa
# Processing Record 32 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 33 of Set 2 | tinskoy
# Processing Record 34 of Set 2 | coahuayana
# Processing Record 35 of Set 2 | nuuk
# Processing Record 36 of Set 2 | ballina
# Processing Record 37 of Set 2 | nyurba
# Processing Record 38 of Set 2 | cermik
# Processing Record 39 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 40 of Set 2 | namibe
# Processing Record 41 of Set 2 | nakasongola
# Processing Record 42 of Set 2 | beringovskiy
# Processing Record 43 of Set 2 | southwick
# Processing Record 44 of Set 2 | samarai
# Processing Record 45 of Set 2 | east london
# Processing Record 46 of Set 2 | port alfred
# Processing Record 47 of Set 2 | taguatinga
# Processing Record 48 of Set 2 | antofagasta
# Processing Record 49 of Set 2 | lasa
# Processing Record 50 of Set 2 | okhotsk
# Processing Record 1 of Set 3 | saint george
# Processing Record 2 of Set 3 | palmer
# Processing Record 3 of Set 3 | snezhnogorsk
# Processing Record 4 of Set 3 | mount gambier
# Processing Record 5 of Set 3 | severo-kurilsk
# Processing Record 6 of Set 3 | chipinge
# Processing Record 7 of Set 3 | kampong thum
# Processing Record 8 of Set 3 | obo
# Processing Record 9 of Set 3 | paamiut
# Processing Record 10 of Set 3 | mizdah
# Processing Record 11 of Set 3 | hasaki
# Processing Record 12 of Set 3 | san quintin
# Processing Record 13 of Set 3 | ancud
# Processing Record 14 of Set 3 | nikolskoye
# Processing Record 15 of Set 3 | amahai
# Processing Record 16 of Set 3 | salta
# Processing Record 17 of Set 3 | saldanha
# Processing Record 18 of Set 3 | qaanaaq
# Processing Record 19 of Set 3 | georgetown
# Processing Record 20 of Set 3 | faanui
# Processing Record 21 of Set 3 | jamestown
# Processing Record 22 of Set 3 | hilo
# Processing Record 23 of Set 3 | atka
# City not found. Skipping...
# Processing Record 24 of Set 3 | kaitangata
# Processing Record 25 of Set 3 | alofi
# Processing Record 26 of Set 3 | mitsamiouli
# Processing Record 27 of Set 3 | carnot
# Processing Record 28 of Set 3 | ossora
# Processing Record 29 of Set 3 | atuona
# Processing Record 30 of Set 3 | broome
# Processing Record 31 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 32 of Set 3 | tigil
# Processing Record 33 of Set 3 | kodiak
# Processing Record 34 of Set 3 | mayor pablo lagerenza
# Processing Record 35 of Set 3 | nome
# Processing Record 36 of Set 3 | narsaq
# Processing Record 37 of Set 3 | mar del plata
# Processing Record 38 of Set 3 | aripuana
# Processing Record 39 of Set 3 | orthez
# Processing Record 40 of Set 3 | caravelas
# Processing Record 41 of Set 3 | westport
# Processing Record 42 of Set 3 | rolim de moura
# City not found. Skipping...
# Processing Record 43 of Set 3 | puerto carreno
# Processing Record 44 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 45 of Set 3 | yar-sale
# Processing Record 46 of Set 3 | sassandra
# Processing Record 47 of Set 3 | princesa isabel
# Processing Record 48 of Set 3 | kruisfontein
# Processing Record 49 of Set 3 | aktash
# Processing Record 50 of Set 3 | wewak
# Processing Record 1 of Set 4 | tlahualilo
# City not found. Skipping...
# Processing Record 2 of Set 4 | ocos
# Processing Record 3 of Set 4 | torbay
# Processing Record 4 of Set 4 | chokurdakh
# Processing Record 5 of Set 4 | hargeysa
# Processing Record 6 of Set 4 | moramanga
# Processing Record 7 of Set 4 | longlac
# City not found. Skipping...
# Processing Record 8 of Set 4 | hobart
# Processing Record 9 of Set 4 | husavik
# Processing Record 10 of Set 4 | zeulenroda
# Processing Record 11 of Set 4 | pawayan
# Processing Record 12 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 13 of Set 4 | codrington
# Processing Record 14 of Set 4 | kavieng
# Processing Record 15 of Set 4 | sarka ghat
# Processing Record 16 of Set 4 | sao filipe
# Processing Record 17 of Set 4 | hithadhoo
# Processing Record 18 of Set 4 | rivers
# Processing Record 19 of Set 4 | saint-philippe
# Processing Record 20 of Set 4 | abilene
# Processing Record 21 of Set 4 | nova odesa
# Processing Record 22 of Set 4 | provideniya
# Processing Record 23 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 24 of Set 4 | ayan
# Processing Record 25 of Set 4 | makrana
# Processing Record 26 of Set 4 | ugoofaaru
# Processing Record 27 of Set 4 | bela
# Processing Record 28 of Set 4 | carnarvon
# Processing Record 29 of Set 4 | satitoa
# City not found. Skipping...
# Processing Record 30 of Set 4 | cherskiy
# Processing Record 31 of Set 4 | mehamn
# Processing Record 32 of Set 4 | srednekolymsk
# Processing Record 33 of Set 4 | kumylzhenskaya
# Processing Record 34 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 35 of Set 4 | raton
# Processing Record 36 of Set 4 | cherdyn
# Processing Record 37 of Set 4 | guerrero negro
# Processing Record 38 of Set 4 | lompoc
# Processing Record 39 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 40 of Set 4 | kabompo
# Processing Record 41 of Set 4 | cape town
# Processing Record 42 of Set 4 | staryy nadym
# Processing Record 43 of Set 4 | bougouni
# Processing Record 44 of Set 4 | flint
# Processing Record 45 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 4 | bouafle
# Processing Record 47 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 48 of Set 4 | taoudenni
# Processing Record 49 of Set 4 | sakakah
# Processing Record 50 of Set 4 | krasnoshchekovo
# Processing Record 1 of Set 5 | khatanga
# Processing Record 2 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 3 of Set 5 | klaksvik
# Processing Record 4 of Set 5 | luderitz
# Processing Record 5 of Set 5 | qaqortoq
# Processing Record 6 of Set 5 | fillmore
# Processing Record 7 of Set 5 | ketchikan
# Processing Record 8 of Set 5 | san cristobal
# Processing Record 9 of Set 5 | chuy
# Processing Record 10 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 11 of Set 5 | cockburn harbour
# City not found. Skipping...
# Processing Record 12 of Set 5 | catio
# Processing Record 13 of Set 5 | nisia floresta
# Processing Record 14 of Set 5 | longyearbyen
# Processing Record 15 of Set 5 | xinyu
# Processing Record 16 of Set 5 | sao domingos do maranhao
# Processing Record 17 of Set 5 | kirkland lake
# Processing Record 18 of Set 5 | balaghat
# Processing Record 19 of Set 5 | sudzha
# Processing Record 20 of Set 5 | sitka
# Processing Record 21 of Set 5 | ondangwa
# Processing Record 22 of Set 5 | kamyshin
# Processing Record 23 of Set 5 | saint-louis
# Processing Record 24 of Set 5 | senneterre
# Processing Record 25 of Set 5 | makakilo city
# Processing Record 26 of Set 5 | kemijarvi
# Processing Record 27 of Set 5 | cidreira
# Processing Record 28 of Set 5 | narayanpet
# Processing Record 29 of Set 5 | tunggol
# Processing Record 30 of Set 5 | oreanda
# City not found. Skipping...
# Processing Record 31 of Set 5 | ponta do sol
# Processing Record 32 of Set 5 | gold coast
# Processing Record 33 of Set 5 | isangel
# Processing Record 34 of Set 5 | balkhash
# Processing Record 35 of Set 5 | dicabisagan
# Processing Record 36 of Set 5 | bonthe
# Processing Record 37 of Set 5 | gotsu
# Processing Record 38 of Set 5 | navahrudak
# Processing Record 39 of Set 5 | virginia beach
# Processing Record 40 of Set 5 | kidal
# Processing Record 41 of Set 5 | barcelos
# Processing Record 42 of Set 5 | hualmay
# Processing Record 43 of Set 5 | tirumala
# Processing Record 44 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 45 of Set 5 | skovde
# City not found. Skipping...
# Processing Record 46 of Set 5 | norman wells
# Processing Record 47 of Set 5 | upata
# Processing Record 48 of Set 5 | necochea
# Processing Record 49 of Set 5 | nkhata bay
# Processing Record 50 of Set 5 | matale
# Processing Record 1 of Set 6 | tuatapere
# Processing Record 2 of Set 6 | pacific grove
# Processing Record 3 of Set 6 | alice springs
# Processing Record 4 of Set 6 | mozhga
# Processing Record 5 of Set 6 | xai-xai
# Processing Record 6 of Set 6 | sao joao da barra
# Processing Record 7 of Set 6 | te anau
# Processing Record 8 of Set 6 | loa janan
# Processing Record 9 of Set 6 | kandi
# Processing Record 10 of Set 6 | isla mujeres
# Processing Record 11 of Set 6 | tiksi
# Processing Record 12 of Set 6 | saskylakh
# Processing Record 13 of Set 6 | adrar
# Processing Record 14 of Set 6 | tessalit
# Processing Record 15 of Set 6 | esperance
# Processing Record 16 of Set 6 | plettenberg bay
# Processing Record 17 of Set 6 | luanda
# Processing Record 18 of Set 6 | nagornskiy
# Processing Record 19 of Set 6 | gornozavodsk
# Processing Record 20 of Set 6 | salalah
# Processing Record 21 of Set 6 | tautira
# Processing Record 22 of Set 6 | comodoro rivadavia
# Processing Record 23 of Set 6 | kloulklubed
# Processing Record 24 of Set 6 | black river
# Processing Record 25 of Set 6 | pampas
# Processing Record 26 of Set 6 | sorbhog
# Processing Record 27 of Set 6 | taldan
# Processing Record 28 of Set 6 | quatre cocos
# Processing Record 29 of Set 6 | sindor
# Processing Record 30 of Set 6 | cayenne
# Processing Record 31 of Set 6 | araouane
# Processing Record 32 of Set 6 | timra
# Processing Record 33 of Set 6 | leningradskiy
# Processing Record 34 of Set 6 | lorengau
# Processing Record 35 of Set 6 | ardistan
# City not found. Skipping...
# Processing Record 36 of Set 6 | aklavik
# Processing Record 37 of Set 6 | angoche
# Processing Record 38 of Set 6 | chicama
# Processing Record 39 of Set 6 | puerto quijarro
# Processing Record 40 of Set 6 | metro
# Processing Record 41 of Set 6 | skagastrond
# City not found. Skipping...
# Processing Record 42 of Set 6 | waddan
# Processing Record 43 of Set 6 | boffa
# Processing Record 44 of Set 6 | meulaboh
# Processing Record 45 of Set 6 | benguela
# Processing Record 46 of Set 6 | tottori
# Processing Record 47 of Set 6 | richards bay
# Processing Record 48 of Set 6 | puerto narino
# Processing Record 49 of Set 6 | yuncheng
# Processing Record 50 of Set 6 | sorland
# Processing Record 1 of Set 7 | wairoa
# Processing Record 2 of Set 7 | hihya
# Processing Record 3 of Set 7 | pisco
# Processing Record 4 of Set 7 | talnakh
# Processing Record 5 of Set 7 | konza
# Processing Record 6 of Set 7 | vardo
# Processing Record 7 of Set 7 | udachnyy
# Processing Record 8 of Set 7 | geraldton
# Processing Record 9 of Set 7 | hovd
# Processing Record 10 of Set 7 | conakry
# Processing Record 11 of Set 7 | mattru
# Processing Record 12 of Set 7 | san policarpo
# Processing Record 13 of Set 7 | yeniseysk
# Processing Record 14 of Set 7 | erenhot
# Processing Record 15 of Set 7 | iqaluit
# Processing Record 16 of Set 7 | cabanas
# Processing Record 17 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 18 of Set 7 | pangnirtung
# Processing Record 19 of Set 7 | batemans bay
# Processing Record 20 of Set 7 | takoradi
# Processing Record 21 of Set 7 | lushunkou
# City not found. Skipping...
# Processing Record 22 of Set 7 | jiangyou
# Processing Record 23 of Set 7 | nagua
# Processing Record 24 of Set 7 | galle
# Processing Record 25 of Set 7 | mehran
# Processing Record 26 of Set 7 | dingle
# Processing Record 27 of Set 7 | ephrata
# Processing Record 28 of Set 7 | arvika
# Processing Record 29 of Set 7 | santona
# Processing Record 30 of Set 7 | kijang
# Processing Record 31 of Set 7 | alta floresta
# Processing Record 32 of Set 7 | pirgos
# Processing Record 33 of Set 7 | kamenka
# Processing Record 34 of Set 7 | mount isa
# Processing Record 35 of Set 7 | egvekinot
# Processing Record 36 of Set 7 | berlevag
# Processing Record 37 of Set 7 | torit
# Processing Record 38 of Set 7 | voyvozh
# Processing Record 39 of Set 7 | northwich
# Processing Record 40 of Set 7 | fortuna
# Processing Record 41 of Set 7 | beitbridge
# Processing Record 42 of Set 7 | isla vista
# Processing Record 43 of Set 7 | sokoto
# Processing Record 44 of Set 7 | mpika
# Processing Record 45 of Set 7 | ereymentau
# Processing Record 46 of Set 7 | elizabeth city
# Processing Record 47 of Set 7 | alice town
# Processing Record 48 of Set 7 | barawe
# City not found. Skipping...
# Processing Record 49 of Set 7 | kahului
# Processing Record 50 of Set 7 | vao
# Processing Record 1 of Set 8 | sisimiut
# Processing Record 2 of Set 8 | lima
# Processing Record 3 of Set 8 | warri
# Processing Record 4 of Set 8 | carutapera
# Processing Record 5 of Set 8 | airai
# Processing Record 6 of Set 8 | umm durman
# City not found. Skipping...
# Processing Record 7 of Set 8 | saint-augustin
# Processing Record 8 of Set 8 | sambava
# Processing Record 9 of Set 8 | de panne
# Processing Record 10 of Set 8 | saint anthony
# Processing Record 11 of Set 8 | anqing
# Processing Record 12 of Set 8 | fairbanks
# Processing Record 13 of Set 8 | picayune
# Processing Record 14 of Set 8 | tilichiki
# Processing Record 15 of Set 8 | cockburn town
# Processing Record 16 of Set 8 | abu dhabi
# Processing Record 17 of Set 8 | berwick
# Processing Record 18 of Set 8 | lata
# Processing Record 19 of Set 8 | marawi
# Processing Record 20 of Set 8 | harlingen
# Processing Record 21 of Set 8 | conceicao do araguaia
# Processing Record 22 of Set 8 | bukit bakri
# City not found. Skipping...
# Processing Record 23 of Set 8 | saint-francois
# Processing Record 24 of Set 8 | wanaka
# Processing Record 25 of Set 8 | hermosillo
# Processing Record 26 of Set 8 | monopoli
# Processing Record 27 of Set 8 | asau
# Processing Record 28 of Set 8 | taksimo
# Processing Record 29 of Set 8 | dangriga
# Processing Record 30 of Set 8 | melfi
# Processing Record 31 of Set 8 | sao felix do xingu
# Processing Record 32 of Set 8 | merauke
# Processing Record 33 of Set 8 | kumluca
# Processing Record 34 of Set 8 | ilulissat
# Processing Record 35 of Set 8 | tiarei
# Processing Record 36 of Set 8 | jiutai
# Processing Record 37 of Set 8 | los llanos de aridane
# Processing Record 38 of Set 8 | thayetmyo
# Processing Record 39 of Set 8 | anadyr
# Processing Record 40 of Set 8 | caramay
# Processing Record 41 of Set 8 | huarmey
# Processing Record 42 of Set 8 | mount pleasant
# Processing Record 43 of Set 8 | hamilton
# Processing Record 44 of Set 8 | grand-lahou
# Processing Record 45 of Set 8 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 46 of Set 8 | zhigansk
# Processing Record 47 of Set 8 | pacifica
# Processing Record 48 of Set 8 | londrina
# Processing Record 49 of Set 8 | kupang
# Processing Record 50 of Set 8 | san patricio
# Processing Record 1 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 9 | fort nelson
# Processing Record 3 of Set 9 | tezu
# Processing Record 4 of Set 9 | kilindoni
# Processing Record 5 of Set 9 | chapais
# Processing Record 6 of Set 9 | doha
# Processing Record 7 of Set 9 | nago
# Processing Record 8 of Set 9 | muyezerskiy
# Processing Record 9 of Set 9 | ilhabela
# Processing Record 10 of Set 9 | santa lucia
# Processing Record 11 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 12 of Set 9 | rach gia
# Processing Record 13 of Set 9 | saint-georges
# Processing Record 14 of Set 9 | kalaleh
# Processing Record 15 of Set 9 | ferzikovo
# Processing Record 16 of Set 9 | brae
# Processing Record 17 of Set 9 | dunedin
# Processing Record 18 of Set 9 | vanavara
# Processing Record 19 of Set 9 | tutoia
# Processing Record 20 of Set 9 | languyan
# Processing Record 21 of Set 9 | kinango
# Processing Record 22 of Set 9 | bambanglipuro
# Processing Record 23 of Set 9 | sabzevar
# Processing Record 24 of Set 9 | ivybridge
# Processing Record 25 of Set 9 | port lincoln
# Processing Record 26 of Set 9 | cabo san lucas
# Processing Record 27 of Set 9 | jinka
# Processing Record 28 of Set 9 | zwedru
# Processing Record 29 of Set 9 | constitucion
# Processing Record 30 of Set 9 | margate
# Processing Record 31 of Set 9 | yantal
# Processing Record 32 of Set 9 | palana
# Processing Record 33 of Set 9 | ocala
# Processing Record 34 of Set 9 | avinurme
# Processing Record 35 of Set 9 | mangaratiba
# Processing Record 36 of Set 9 | payo
# Processing Record 37 of Set 9 | pechora
# Processing Record 38 of Set 9 | benito juarez
# Processing Record 39 of Set 9 | porto walter
# Processing Record 40 of Set 9 | agadez
# Processing Record 41 of Set 9 | pauini
# Processing Record 42 of Set 9 | yumen
# Processing Record 43 of Set 9 | ankang
# Processing Record 44 of Set 9 | olafsvik
# Processing Record 45 of Set 9 | swan hill
# Processing Record 46 of Set 9 | tiznit
# Processing Record 47 of Set 9 | locri
# Processing Record 48 of Set 9 | utila
# City not found. Skipping...
# Processing Record 49 of Set 9 | sinnamary
# Processing Record 50 of Set 9 | visby
# Processing Record 1 of Set 10 | dodge city
# Processing Record 2 of Set 10 | maceio
# Processing Record 3 of Set 10 | sollies-pont
# Processing Record 4 of Set 10 | strai
# Processing Record 5 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 10 | darlington
# Processing Record 7 of Set 10 | taltal
# Processing Record 8 of Set 10 | florida
# Processing Record 9 of Set 10 | qandahar
# City not found. Skipping...
# Processing Record 10 of Set 10 | san ignacio
# Processing Record 11 of Set 10 | oranjemund
# Processing Record 12 of Set 10 | hit
# Processing Record 13 of Set 10 | bambous virieux
# Processing Record 14 of Set 10 | abu samrah
# Processing Record 15 of Set 10 | hope
# Processing Record 16 of Set 10 | naze
# Processing Record 17 of Set 10 | cozumel
# Processing Record 18 of Set 10 | olinda
# Processing Record 19 of Set 10 | gat
# Processing Record 20 of Set 10 | vila franca do campo
# Processing Record 21 of Set 10 | sabha
# Processing Record 22 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 23 of Set 10 | ardakan
# Processing Record 24 of Set 10 | walvis bay
# Processing Record 25 of Set 10 | chumikan
# Processing Record 26 of Set 10 | tahe
# Processing Record 27 of Set 10 | myitkyina
# Processing Record 28 of Set 10 | sao miguel
# City not found. Skipping...
# Processing Record 29 of Set 10 | jutai
# Processing Record 30 of Set 10 | horn
# Processing Record 31 of Set 10 | souillac
# Processing Record 32 of Set 10 | hun
# Processing Record 33 of Set 10 | bilma
# Processing Record 34 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 35 of Set 10 | burnie
# Processing Record 36 of Set 10 | pemba
# Processing Record 37 of Set 10 | calbuco
# Processing Record 38 of Set 10 | saint-joseph
# Processing Record 39 of Set 10 | letterkenny
# Processing Record 40 of Set 10 | ambilobe
# Processing Record 41 of Set 10 | carmaux
# Processing Record 44 of Set 10 | komsomolsk
# Processing Record 45 of Set 10 | komsomolskiy
# Processing Record 46 of Set 10 | kuvshinovo
# Processing Record 47 of Set 10 | synya
# Processing Record 48 of Set 10 | baghdad
# Processing Record 49 of Set 10 | yarega
# Processing Record 50 of Set 10 | itarema
# Processing Record 1 of Set 11 | san juan
# Processing Record 2 of Set 11 | kieta
# Processing Record 3 of Set 11 | riviere-au-renard
# Processing Record 4 of Set 11 | rio grande
# Processing Record 5 of Set 11 | acapulco
# Processing Record 6 of Set 11 | fuerte olimpo
# Processing Record 7 of Set 11 | dwarka
# Processing Record 8 of Set 11 | avera
# Processing Record 9 of Set 11 | contamana
# Processing Record 10 of Set 11 | didao
# Processing Record 11 of Set 11 | coihueco
# Processing Record 12 of Set 11 | kati
# Processing Record 13 of Set 11 | lovozero
# Processing Record 14 of Set 11 | coihaique
# Processing Record 15 of Set 11 | trincomalee
# Processing Record 16 of Set 11 | emerald
# Processing Record 17 of Set 11 | zlobin
# Processing Record 18 of Set 11 | micheweni
# Processing Record 19 of Set 11 | cayambe
# Processing Record 20 of Set 11 | sharya
# Processing Record 21 of Set 11 | bukachacha
# Processing Record 22 of Set 11 | sauda
# Processing Record 23 of Set 11 | caruray
# Processing Record 24 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 25 of Set 11 | lavrentiya
# Processing Record 26 of Set 11 | hobyo
# Processing Record 27 of Set 11 | eldorado
# Processing Record 28 of Set 11 | do gonbadan
# Processing Record 29 of Set 11 | hastings
# Processing Record 30 of Set 11 | lalomanu
# City not found. Skipping...
# Processing Record 31 of Set 11 | yulara
# Processing Record 32 of Set 11 | longhua
# Processing Record 33 of Set 11 | durant
# Processing Record 34 of Set 11 | sampit
# Processing Record 35 of Set 11 | oriximina
# Processing Record 36 of Set 11 | port-cartier
# Processing Record 37 of Set 11 | chimbote
# Processing Record 38 of Set 11 | greeley
# Processing Record 39 of Set 11 | flinders
# Processing Record 40 of Set 11 | santa maria
# Processing Record 41 of Set 11 | hakui
# Processing Record 42 of Set 11 | tasbuget
# City not found. Skipping...
# Processing Record 43 of Set 11 | baffa
# Processing Record 44 of Set 11 | sakaiminato
# Processing Record 45 of Set 11 | rock sound
# Processing Record 46 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 47 of Set 11 | abbeville
# Processing Record 48 of Set 11 | chauk
# Processing Record 49 of Set 11 | okha
# Processing Record 50 of Set 11 | la ronge
# Processing Record 1 of Set 12 | garissa
# Processing Record 2 of Set 12 | goma
# Processing Record 3 of Set 12 | asayita
# City not found. Skipping...
# Processing Record 4 of Set 12 | mastic
# Processing Record 5 of Set 12 | macomer
# Processing Record 6 of Set 12 | safaga
# Processing Record 7 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 8 of Set 12 | whitehorse
# Processing Record 9 of Set 12 | catamarca
# Processing Record 10 of Set 12 | kutum
# Processing Record 11 of Set 12 | itaueira
# Processing Record 12 of Set 12 | kikwit
# Processing Record 13 of Set 12 | batagay
# Processing Record 14 of Set 12 | fevralsk
# City not found. Skipping...
# Processing Record 15 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 16 of Set 12 | maniitsoq
# Processing Record 17 of Set 12 | mumford
# Processing Record 18 of Set 12 | charlestown
# Processing Record 19 of Set 12 | mackay
# Processing Record 20 of Set 12 | dutse
# Processing Record 21 of Set 12 | pankovka
# Processing Record 22 of Set 12 | burhaniye
# Processing Record 23 of Set 12 | neosho
# Processing Record 24 of Set 12 | padang
# Processing Record 25 of Set 12 | beidao
# Processing Record 26 of Set 12 | alenquer
# Processing Record 27 of Set 12 | camana
# Processing Record 28 of Set 12 | bilibino
# Processing Record 29 of Set 12 | papillion
# Processing Record 30 of Set 12 | zhangye
# Processing Record 31 of Set 12 | atherton
# Processing Record 32 of Set 12 | badou
# Processing Record 33 of Set 12 | puerto escondido
# Processing Record 34 of Set 12 | ponta delgada
# Processing Record 35 of Set 12 | jahazpur
# Processing Record 36 of Set 12 | tsiroanomandidy
# Processing Record 37 of Set 12 | chara
# Processing Record 38 of Set 12 | kokopo
# Processing Record 39 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 40 of Set 12 | la roche-sur-yon
# Processing Record 41 of Set 12 | safwah
# City not found. Skipping...
# Processing Record 42 of Set 12 | lagoa
# Processing Record 43 of Set 12 | faya
# Processing Record 44 of Set 12 | boyolangu
# Processing Record 45 of Set 12 | prokuplje
# Processing Record 46 of Set 12 | kurilsk
# Processing Record 47 of Set 12 | stege
# Processing Record 48 of Set 12 | bahia blanca
# Processing Record 49 of Set 12 | navoloki
# Processing Record 50 of Set 12 | edd
# Processing Record 1 of Set 13 | gawler
# Processing Record 2 of Set 13 | urdzhar
# City not found. Skipping...
# Processing Record 3 of Set 13 | beihai
# Processing Record 4 of Set 13 | mnogovershinnyy
# Processing Record 5 of Set 13 | torrelavega
# Processing Record 6 of Set 13 | neyshabur
# Processing Record 7 of Set 13 | linqiong
# Processing Record 8 of Set 13 | awjilah
# Processing Record 9 of Set 13 | kalmar
# Processing Record 10 of Set 13 | madanapalle
# Processing Record 11 of Set 13 | maghama
# City not found. Skipping...
# Processing Record 12 of Set 13 | iquique
# Processing Record 13 of Set 13 | kwinana
# Processing Record 14 of Set 13 | esso
# Processing Record 15 of Set 13 | oktyabrskoye
# Processing Record 16 of Set 13 | la asuncion
# Processing Record 17 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 18 of Set 13 | stroud
# Processing Record 19 of Set 13 | ondo
# Processing Record 20 of Set 13 | marsh harbour
# Processing Record 21 of Set 13 | derzhavinsk
# Processing Record 22 of Set 13 | kungurtug
# Processing Record 23 of Set 13 | santa cruz
# Processing Record 24 of Set 13 | ullapool
# Processing Record 25 of Set 13 | damghan
# Processing Record 26 of Set 13 | fukue
# Processing Record 27 of Set 13 | dalvik
# Processing Record 28 of Set 13 | qasigiannguit
# Processing Record 29 of Set 13 | bay roberts
# Processing Record 30 of Set 13 | belyy yar
# Processing Record 31 of Set 13 | yaan
# Processing Record 32 of Set 13 | kedrovyy
# Processing Record 33 of Set 13 | namatanai
# Processing Record 34 of Set 13 | rypefjord
# Processing Record 35 of Set 13 | hvolsvollur
# Processing Record 36 of Set 13 | ahipara
# Processing Record 37 of Set 13 | megion
# Processing Record 38 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 39 of Set 13 | caaguazu
# Processing Record 40 of Set 13 | inirida
# Processing Record 41 of Set 13 | miranda
# Processing Record 42 of Set 13 | krasnoselkup
# Processing Record 43 of Set 13 | moree
# Processing Record 44 of Set 13 | clovis
# Processing Record 45 of Set 13 | yilan
# Processing Record 46 of Set 13 | kem
# Processing Record 47 of Set 13 | srandakan
# Processing Record 48 of Set 13 | hervey bay
# Processing Record 49 of Set 13 | eydhafushi
# Processing Record 50 of Set 13 | pangai
# Processing Record 1 of Set 14 | riberalta
# Processing Record 2 of Set 14 | grand gaube
# Processing Record 3 of Set 14 | zanjan
# Processing Record 4 of Set 14 | kovdor
# Processing Record 5 of Set 14 | tambura
# Processing Record 6 of Set 14 | ulaanbaatar
# Processing Record 7 of Set 14 | lunenburg
# Processing Record 8 of Set 14 | jining
# Processing Record 9 of Set 14 | gobabis
# Processing Record 10 of Set 14 | nogliki
# Processing Record 11 of Set 14 | gabu
# Processing Record 12 of Set 14 | mullaitivu
# City not found. Skipping...
# Processing Record 13 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 14 of Set 14 | aitape
# Processing Record 15 of Set 14 | kaabong
# Processing Record 16 of Set 14 | dzilam gonzalez
# Processing Record 17 of Set 14 | klaipeda
# Processing Record 18 of Set 14 | lake havasu city
# Processing Record 19 of Set 14 | quelimane
# Processing Record 20 of Set 14 | nandurbar
# Processing Record 21 of Set 14 | shakawe
# Processing Record 22 of Set 14 | banjar
# Processing Record 23 of Set 14 | korem
# Processing Record 24 of Set 14 | azogues
# Processing Record 25 of Set 14 | teya
# Processing Record 26 of Set 14 | broken hill
# Processing Record 27 of Set 14 | galesong
# Processing Record 28 of Set 14 | alexandria
# Processing Record 29 of Set 14 | barra patuca
# Processing Record 30 of Set 14 | chimoio
# Processing Record 31 of Set 14 | blackwater
# Processing Record 32 of Set 14 | kusti
# Processing Record 33 of Set 14 | cotija
# City not found. Skipping...
# Processing Record 34 of Set 14 | sokna
# Processing Record 35 of Set 14 | bandarbeyla
# Processing Record 36 of Set 14 | havoysund
# Processing Record 37 of Set 14 | bichura
# Processing Record 38 of Set 14 | xining
# Processing Record 39 of Set 14 | dickinson
# Processing Record 40 of Set 14 | kapuskasing
# Processing Record 41 of Set 14 | iskateley
# Processing Record 42 of Set 14 | vostok
# Processing Record 43 of Set 14 | beaver dam
# Processing Record 44 of Set 14 | palmeirais
# Processing Record 45 of Set 14 | agadir
# Processing Record 46 of Set 14 | nishihara
# Processing Record 47 of Set 14 | kibala
# Processing Record 48 of Set 14 | portland
# Processing Record 49 of Set 14 | sao lourenco do sul
# Processing Record 50 of Set 14 | skibbereen
# Processing Record 1 of Set 15 | iranshahr
# Processing Record 2 of Set 15 | north bend
# Processing Record 3 of Set 15 | bayji
# Processing Record 4 of Set 15 | axim
# Processing Record 5 of Set 15 | yamada
# Processing Record 6 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 7 of Set 15 | kabo
# Processing Record 8 of Set 15 | chesma
# Processing Record 9 of Set 15 | vangaindrano
# Processing Record 10 of Set 15 | raga
# Processing Record 11 of Set 15 | honiara
# Processing Record 12 of Set 15 | choma
# Processing Record 13 of Set 15 | changde
# Processing Record 14 of Set 15 | pizarro
# Processing Record 15 of Set 15 | sibu
# Processing Record 16 of Set 15 | haibowan
# City not found. Skipping...
# Processing Record 17 of Set 15 | mikhaylovsk
# Processing Record 18 of Set 15 | ostrovnoy
# Processing Record 19 of Set 15 | jalu
# Processing Record 20 of Set 15 | portsmouth
# Processing Record 21 of Set 15 | mogadishu
# Processing Record 22 of Set 15 | sibolga
# Processing Record 23 of Set 15 | amapa
# Processing Record 24 of Set 15 | baturaja
# Processing Record 25 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 26 of Set 15 | alappuzha
# Processing Record 27 of Set 15 | tuggurt
# City not found. Skipping...
# Processing Record 28 of Set 15 | thinadhoo
# Processing Record 29 of Set 15 | uthal
# Processing Record 30 of Set 15 | maumere
# Processing Record 31 of Set 15 | kamuli
# Processing Record 32 of Set 15 | price
# Processing Record 33 of Set 15 | horsham
# Processing Record 34 of Set 15 | waipawa
# Processing Record 35 of Set 15 | la libertad
# Processing Record 36 of Set 15 | kiama
# Processing Record 37 of Set 15 | morobuan
# Processing Record 38 of Set 15 | paraiso
# Processing Record 39 of Set 15 | ngunguru
# Processing Record 40 of Set 15 | beatrice
# Processing Record 41 of Set 15 | la palma
# Processing Record 42 of Set 15 | asosa
# Processing Record 43 of Set 15 | jamame
# Processing Record 44 of Set 15 | morros
# Processing Record 45 of Set 15 | shitkino
# Processing Record 46 of Set 15 | finspang
# Processing Record 47 of Set 15 | severo-yeniseyskiy
# Processing Record 48 of Set 15 | clarksville
# Processing Record 49 of Set 15 | lakes entrance
# Processing Record 50 of Set 15 | randolph
# Processing Record 1 of Set 16 | iquitos
# Processing Record 2 of Set 16 | kawana waters
# City not found. Skipping...
# Processing Record 3 of Set 16 | neiafu
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
print(len(city_data))
# Out:
# 689

# %%
type(city_data)
# Out:
# list

# %%
#Save the list to a dataframe and change the order of the column
city_data_df = pd.DataFrame(city_data)
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current description"]
city_data_df=city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Barkhan      PK  29.8977   69.5256     91.71         6           0
# 1       Avarua      CK -21.2078 -159.7750     75.25        94          75
# 2  Clyde River      CA  70.4692  -68.5914     16.03        92         100
# 3     Bengkulu      ID  -3.8004  102.2655     86.05        67          74
# 4      Rikitea      PF -23.1203 -134.9692     76.87        82           9
# 5   Butaritari      KI   3.0707  172.7902     80.98        79          67
# 6       Sabang      ID   5.8933   95.3214     84.15        74         100
# 7      La Cruz      MX  23.9167 -106.9000     77.27        67          75
# 8        Vaini      TO -21.2000 -175.2000     75.36        69          75
# 9          Bud      US  39.4470  -86.1758     75.04        86           1
#
#    Wind Speed Current description
# 0        8.16           clear sky
# 1       10.36         shower rain
# 2       18.41          light snow
# 3       17.27       broken clouds
# 4       19.73          light rain
# 5        9.69       broken clouds
# 6       21.07          light rain
# 7        4.88       broken clouds
# 8        9.22       broken clouds
# 9        7.36           clear sky

# %%
city_data_df.count()
# Out:
# City                   689
# Country                689
# Lat                    689
# Lng                    689
# Max Temp               689
# Humidity               689
# Cloudiness             689
# Wind Speed             689
# Current description    689
# dtype: int64

# %%
city_data_df.rename(columns={"Current description": "Current Description"}, inplace=True)
city_data_df.head()
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Barkhan      PK  29.8977   69.5256     91.71         6           0
# 1       Avarua      CK -21.2078 -159.7750     75.25        94          75
# 2  Clyde River      CA  70.4692  -68.5914     16.03        92         100
# 3     Bengkulu      ID  -3.8004  102.2655     86.05        67          74
# 4      Rikitea      PF -23.1203 -134.9692     76.87        82           9
#
#    Wind Speed Current Description
# 0        8.16           clear sky
# 1       10.36         shower rain
# 2       18.41          light snow
# 3       17.27       broken clouds
# 4       19.73          light rain

# %%
# Export the City_Data into a CSV.
city_data_df.to_csv("WeatherPy_Database.csv")
